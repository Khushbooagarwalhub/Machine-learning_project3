# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import (
    VGG19, 
    preprocess_input, 
    decode_predictions
)

# %%
# Load the VGG19 model
# https://keras.io/applications/#VGG19
model = VGG19(include_top=True, weights='imagenet')

# %%
# Define default image size for VGG19
image_size = (224, 224)

# %%
# Load the image and resize to default image size
image_path = os.path.join("Images","Draft Imgs","JPEGImages", "applauding_042.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)

# %%
# Preprocess image for model prediction
# This step handles scaling and normalization for VGG19
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step
# Predicted: [[('n04350905', 'suit', 0.16674192), ('n02883205', 'bow_tie', 0.16110723), ('n02111129', 'Leonberg', 0.06555827)]]

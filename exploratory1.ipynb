# %%
import numpy as np
import pandas as pd
import os
from pandas import DataFrame
import csv

# %%
df = pd.read_fwf('WISDM_ar_latest/WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt',headers='none')
print(df)
# Out:
#         33,Jogging,49105962326000,-0.6946377,12.680544,0.50395286;
# 0        33,Jogging,49106062271000,5.012288,11.264028,0...
# 1        33,Jogging,49106112167000,4.903325,10.882658,-...
# 2        33,Jogging,49106222305000,-0.61291564,18.49643...
# 3        33,Jogging,49106332290000,-1.1849703,12.108489...
# 4        33,Jogging,49106442306000,1.3756552,-2.4925237...
# ...                                                    ...
# 1098198           19,Sitting,131623331483000,9,-1.57,1.69;
# 1098199        19,Sitting,131623371431000,9.04,-1.46,1.73;
# 1098200        19,Sitting,131623411592000,9.08,-1.38,1.69;
# 1098201           19,Sitting,131623491487000,9,-1.46,1.73;
# 1098202        19,Sitting,131623531465000,8.88,-1.33,1.61;
#
# [1098203 rows x 1 columns]

# %%
f = open("WISDM_ar_latest/WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt", "r")
print(f.readline())
# Out:
# 33,Jogging,49105962326000,-0.6946377,12.680544,0.50395286;

# %%
# from pandas import DataFrame
# import pandas as pd
# import os


# def get_file_name( path):
#     return os.path.basename(path).split(".")[0].strip().lower() 


# name = get_file_name('./inputs/dist.txt')
# with open('./inputs/dist.txt') as f:
#     df = DataFrame(0.0, index=[1,2,3], columns=[1,2,3])
#     for line in f:
#         data = line.strip().split()
#         row,column,value = [int(i) if i.isdigit() else float(i) for i in data]
#         df.set_value(row,column,value)
# m[name] = df

# %%
pd.read_fwf('WISDM_ar_latest/WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt',sep=",", header=None)
# Out:
#                                                          0
# 0        33,Jogging,49105962326000,-0.6946377,12.680544...
# 1        33,Jogging,49106062271000,5.012288,11.264028,0...
# 2        33,Jogging,49106112167000,4.903325,10.882658,-...
# 3        33,Jogging,49106222305000,-0.61291564,18.49643...
# 4        33,Jogging,49106332290000,-1.1849703,12.108489...
# ...                                                    ...
# 1098199           19,Sitting,131623331483000,9,-1.57,1.69;
# 1098200        19,Sitting,131623371431000,9.04,-1.46,1.73;
# 1098201        19,Sitting,131623411592000,9.08,-1.38,1.69;
# 1098202           19,Sitting,131623491487000,9,-1.46,1.73;
# 1098203        19,Sitting,131623531465000,8.88,-1.33,1.61;
#
# [1098204 rows x 1 columns]

# %%
data = pd.read_csv('WISDM_ar_latest/WISDM_ar_v1.1/WISDM_ar_v1.1.csv')
data
# Out:
#          user_id activity        timestamp     acc_x      acc_y     acc_z
# 0             33  Jogging   49105962326000 -0.694638  12.680544  0.503953
# 1             33  Jogging   49106062271000  5.012288  11.264028  0.953424
# 2             33  Jogging   49106112167000  4.903325  10.882658 -0.081722
# 3             33  Jogging   49106222305000 -0.612916  18.496431  3.023717
# 4             33  Jogging   49106332290000 -1.184970  12.108489  7.205164
# ...          ...      ...              ...       ...        ...       ...
# 1098204       19  Sitting  131623331483000  9.000000  -1.570000  1.690000
# 1098205       19  Sitting  131623371431000  9.040000  -1.460000  1.730000
# 1098206       19  Sitting  131623411592000  9.080000  -1.380000  1.690000
# 1098207       19  Sitting  131623491487000  9.000000  -1.460000  1.730000
# 1098208       19  Sitting  131623531465000  8.880000  -1.330000  1.610000
#
# [1098209 rows x 6 columns]

# %%
data.dtypes
# Out:
# user_id        int64
# activity      object
# timestamp      int64
# acc_x        float64
# acc_y        float64
# acc_z        float64
# dtype: object

# %%
data.head(50)
# Out:
#     user_id activity       timestamp      acc_x      acc_y      acc_z
# 0        33  Jogging  49105962326000  -0.694638  12.680544   0.503953
# 1        33  Jogging  49106062271000   5.012288  11.264028   0.953424
# 2        33  Jogging  49106112167000   4.903325  10.882658  -0.081722
# 3        33  Jogging  49106222305000  -0.612916  18.496431   3.023717
# 4        33  Jogging  49106332290000  -1.184970  12.108489   7.205164
# 5        33  Jogging  49106442306000   1.375655  -2.492524  -6.510526
# 6        33  Jogging  49106542312000  -0.612916  10.569390   5.706926
# 7        33  Jogging  49106652389000  -0.503953  13.947236   7.055340
# 8        33  Jogging  49106762313000  -8.430995  11.413852   5.134871
# 9        33  Jogging  49106872299000   0.953424   1.375655   1.648062
# 10       33  Jogging  49106982315000  -8.199450  19.572440   2.724070
# 11       33  Jogging  49107092330000   1.416516   5.788648   2.982856
# ...

# %%
#find the different activities performed
data.activity.unique()
# Out:
# array(['Jogging', 'Walking', 'Upstairs', 'Downstairs', 'Sitting',
#        'Standing'], dtype=object)

# %%
data.user_id.unique()
# Out:
# array([33, 17, 20, 29, 13, 15,  6, 27, 36, 18, 32, 35, 11, 16,  5, 10, 28,
#        26, 14, 24, 12, 23,  4, 30, 34,  8, 31, 21,  3, 22,  1,  9, 25,  2,
#         7, 19], dtype=int64)

# %%
data.user_id.nunique()
# Out:
# 36

# %%
count = data.groupby(['activity']).count() 
print(count)
# Out:
#             user_id  timestamp   acc_x   acc_y   acc_z
# activity
# Downstairs   100427     100427  100427  100427  100427
# Jogging      342179     342179  342179  342179  342179
# Sitting       59939      59939   59939   59939   59939
# Standing      48395      48395   48395   48395   48395
# Upstairs     122869     122869  122869  122869  122869
# Walking      424400     424400  424400  424400  424400

# %%
import matplotlib.pyplot as plt

# %%
ax = data['activity'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Count of activity")
ax.set_xlabel("activity") 
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data['activity'].value_counts().plot(kind = 'pie',wedgeprops={'alpha':0.5})
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})

# %%
data['acc_x'].plot(linewidth=0.5);

# %%
data_running = data[data['activity'] =='Jogging']
data_running
data_running_filter = data_running[:200]
data_running_filter
# Out:
#      user_id activity       timestamp     acc_x      acc_y     acc_z
# 0         33  Jogging  49105962326000 -0.694638  12.680544  0.503953
# 1         33  Jogging  49106062271000  5.012288  11.264028  0.953424
# 2         33  Jogging  49106112167000  4.903325  10.882658 -0.081722
# 3         33  Jogging  49106222305000 -0.612916  18.496431  3.023717
# 4         33  Jogging  49106332290000 -1.184970  12.108489  7.205164
# ..       ...      ...             ...       ...        ...       ...
# 195       33  Jogging  49126442337000 -0.953424  17.052675  4.481094
# 196       33  Jogging  49126542251000  3.296124   4.290410  0.081722
# 197       33  Jogging  49126652297000 -6.510526  18.115063 -5.856750
# 198       33  Jogging  49126762313000  5.979332  10.501288  7.123442
# 199       33  Jogging  49126862258000 -0.572055  -6.129157 -9.112013
#
# [200 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(15, 7))

# Add the x-axis and the y-axis to the plot
ax.plot(data_running_filter['timestamp'],
        data_running_filter['acc_x'],
        color='purple')

ax.set(xlabel="timestamp",
       ylabel="X acceleration",
       title="jogging")


fig, ax = plt.subplots(figsize=(15, 7))

ax.plot(data_running_filter['timestamp'],
        data_running_filter['acc_y'],
        color='purple')

ax.set(xlabel="timestamp",
       ylabel="y acceleration",
       title="jogging")



fig, ax = plt.subplots(figsize=(15, 7))

ax.plot(data_running_filter['timestamp'],
        data_running_filter['acc_z'],
        color='purple')

ax.set(xlabel="timestamp",
       ylabel="z acceleration",
       title="jogging")
# Out:
# [Text(0, 0.5, 'z acceleration'),
#  Text(0.5, 0, 'timestamp'),
#  Text(0.5, 1.0, 'jogging')]

# %%
data_train = data[data['user_id'] >20]
data_test =  data[data['user_id'] <=15]

# %%
data_train.head(40)
# Out:
#     user_id activity       timestamp     acc_x      acc_y      acc_z
# 0        33  Jogging  49105962326000 -0.694638  12.680544   0.503953
# 1        33  Jogging  49106062271000  5.012288  11.264028   0.953424
# 2        33  Jogging  49106112167000  4.903325  10.882658  -0.081722
# 3        33  Jogging  49106222305000 -0.612916  18.496431   3.023717
# 4        33  Jogging  49106332290000 -1.184970  12.108489   7.205164
# 5        33  Jogging  49106442306000  1.375655  -2.492524  -6.510526
# 6        33  Jogging  49106542312000 -0.612916  10.569390   5.706926
# 7        33  Jogging  49106652389000 -0.503953  13.947236   7.055340
# 8        33  Jogging  49106762313000 -8.430995  11.413852   5.134871
# 9        33  Jogging  49106872299000  0.953424   1.375655   1.648062
# 10       33  Jogging  49106982315000 -8.199450  19.572440   2.724070
# 11       33  Jogging  49107092330000  1.416516   5.788648   2.982856
# 12       33  Jogging  49107202316000 -1.879608  -2.982856  -0.299648
# ...

# %%
data_test.head(40)
# Out:
#         user_id activity      timestamp  acc_x  acc_y      acc_z
# 100379       13  Walking  1047162303000  -2.41   5.18   1.539099
# 100380       13  Walking  1047212260000  -0.30   1.73  -0.503953
# 100381       13  Walking  1047262309000   1.27  11.03   2.560625
# 100382       13  Walking  1047312266000  -1.42  14.75   8.158588
# 100383       13  Walking  1047362285000  -0.89  10.65   3.990762
# 100384       13  Walking  1047412273000  -2.22  13.10  -5.243834
# 100385       13  Walking  1047462291000   0.19  11.60   4.944186
# 100386       13  Walking  1047512279000  -2.45   9.85  -3.786457
# 100387       13  Walking  1047562266000   0.93  10.15  -0.299648
# 100388       13  Walking  1047612285000   0.00   9.38  -1.225831
# 100389       13  Walking  1047662364000   1.04   8.47  -0.081722
# 100390       13  Walking  1047712382000   2.49   9.66   1.688923
# 100391       13  Walking  1047762279000  -0.19   9.47   1.266692
# ...

# %%
data_reformat = pd.read_csv('WISDM_ar_latest/WISDM_ar_v1.1/reformat_data.csv')
data_reformat
# Out:
#       unique_id  user_id    x0    x1    x2    x3    x4    x5    x6    x7  ...  \
# 0             1       33  0.04  0.09  0.14  0.12  0.11  0.10  0.08  0.13  ...
# 1             2       33  0.12  0.12  0.06  0.07  0.11  0.10  0.11  0.09  ...
# 2             3       33  0.14  0.09  0.11  0.09  0.09  0.11  0.12  0.08  ...
# 3             4       33  0.06  0.10  0.09  0.09  0.11  0.07  0.12  0.10  ...
# 4             5       33  0.12  0.11  0.10  0.08  0.10  0.14  0.10  0.11  ...
# ...         ...      ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 5413        382       19  0.18  0.17  0.00  0.00  0.28  0.00  0.00  0.00  ...
# 5414        383       19  0.11  0.15  0.00  0.00  0.34  0.00  0.00  0.00  ...
# 5415        384       19  0.18  0.07  0.00  0.00  0.22  0.00  0.00  0.00  ...
# 5416        385       19  0.17  0.25  0.00  0.00  0.23  0.00  0.00  0.00  ...
# 5417        386       19  0.05  0.08  0.00  0.00  0.09  0.00  0.00  0.00  ...
#
# ...

# %%
from sklearn import preprocessing
# Define column name of the label vector
LABEL = 'ActivityEncoded'
# Transform the labels from String to Integer via LabelEncoder
le = preprocessing.LabelEncoder()
# Add a new column to the existing DataFrame with the encoded values
data_reformat[LABEL] = le.fit_transform(data_reformat['class'].values.ravel())
data_reformat
# Out:
#       unique_id  user_id    x0    x1    x2    x3    x4    x5    x6    x7  ...  \
# 0             1       33  0.04  0.09  0.14  0.12  0.11  0.10  0.08  0.13  ...
# 1             2       33  0.12  0.12  0.06  0.07  0.11  0.10  0.11  0.09  ...
# 2             3       33  0.14  0.09  0.11  0.09  0.09  0.11  0.12  0.08  ...
# 3             4       33  0.06  0.10  0.09  0.09  0.11  0.07  0.12  0.10  ...
# 4             5       33  0.12  0.11  0.10  0.08  0.10  0.14  0.10  0.11  ...
# ...         ...      ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 5413        382       19  0.18  0.17  0.00  0.00  0.28  0.00  0.00  0.00  ...
# 5414        383       19  0.11  0.15  0.00  0.00  0.34  0.00  0.00  0.00  ...
# 5415        384       19  0.18  0.07  0.00  0.00  0.22  0.00  0.00  0.00  ...
# 5416        385       19  0.17  0.25  0.00  0.00  0.23  0.00  0.00  0.00  ...
# 5417        386       19  0.05  0.08  0.00  0.00  0.09  0.00  0.00  0.00  ...
#
# ...

# %%
from numpy.random import seed
seed(1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets

# %%
data_train = data_reformat[data_reformat['user_id'] >20]
data_test =  data_reformat[data_reformat['user_id'] <=20]

# %%
data_train.head(40)
# Out:
#     unique_id  user_id    x0    x1    x2    x3    x4    x5    x6    x7  ...  \
# 0           1       33  0.04  0.09  0.14  0.12  0.11  0.10  0.08  0.13  ...
# 1           2       33  0.12  0.12  0.06  0.07  0.11  0.10  0.11  0.09  ...
# 2           3       33  0.14  0.09  0.11  0.09  0.09  0.11  0.12  0.08  ...
# 3           4       33  0.06  0.10  0.09  0.09  0.11  0.07  0.12  0.10  ...
# 4           5       33  0.12  0.11  0.10  0.08  0.10  0.14  0.10  0.11  ...
# 5           6       33  0.09  0.09  0.10  0.12  0.08  0.06  0.09  0.08  ...
# 6           7       33  0.12  0.12  0.12  0.13  0.15  0.11  0.08  0.09  ...
# 7           8       33  0.10  0.10  0.10  0.10  0.11  0.11  0.09  0.09  ...
# 8           9       33  0.08  0.07  0.08  0.08  0.05  0.08  0.14  0.10  ...
# 9          10       33  0.01  0.00  0.00  0.01  0.01  0.01  0.01  0.01  ...
# 10         11       33  0.03  0.08  0.07  0.07  0.09  0.13  0.14  0.16  ...
# ...

# %%
data_test.head(40)
# Out:
#     unique_id  user_id    x0    x1    x2    x3    x4    x5    x6    x7  ...  \
# 47         48       17  0.15  0.24  0.10  0.08  0.11  0.09  0.08  0.03  ...
# 48         49       17  0.08  0.05  0.10  0.10  0.13  0.14  0.10  0.11  ...
# 49         50       17  0.10  0.09  0.11  0.08  0.10  0.14  0.08  0.11  ...
# 50         51       17  0.12  0.11  0.08  0.08  0.11  0.10  0.15  0.09  ...
# 51         52       17  0.13  0.12  0.05  0.10  0.09  0.09  0.12  0.11  ...
# 52         53       17  0.13  0.09  0.10  0.08  0.11  0.08  0.11  0.10  ...
# 53         54       17  0.14  0.08  0.08  0.14  0.10  0.08  0.09  0.08  ...
# 54         55       17  0.12  0.10  0.12  0.09  0.09  0.09  0.10  0.12  ...
# 55         56       17  0.09  0.09  0.11  0.13  0.08  0.10  0.11  0.10  ...
# 56         57       17  0.11  0.09  0.10  0.12  0.10  0.07  0.10  0.08  ...
# 57         58       17  0.06  0.09  0.12  0.09  0.14  0.12  0.12  0.12  ...
# ...

# %%
y =data_reformat["ActivityEncoded"]
y.head(10)
# Out:
# 0    1
# 1    1
# 2    1
# 3    5
# 4    5
# 5    5
# 6    4
# 7    4
# 8    4
# 9    4
# Name: ActivityEncoded, dtype: int32

# %%
x = data_reformat[['x0','x1','x2','x3','x4','x5','x6','x7','x8','x9','y1','y2','y3','y4','y5','y6','y7','y8','y9','z1','z2','z3','z4','z5','z6','z7','z8','z9']]
#feature_names = x.columns
x.head()
# Out:
#      x0    x1    x2    x3    x4    x5    x6    x7    x8    x9  ...    y9  \
# 0  0.04  0.09  0.14  0.12  0.11  0.10  0.08  0.13  0.13  0.08  ...  0.03
# 1  0.12  0.12  0.06  0.07  0.11  0.10  0.11  0.09  0.12  0.10  ...  0.04
# 2  0.14  0.09  0.11  0.09  0.09  0.11  0.12  0.08  0.05  0.12  ...  0.06
# 3  0.06  0.10  0.09  0.09  0.11  0.07  0.12  0.10  0.14  0.14  ...  0.11
# 4  0.12  0.11  0.10  0.08  0.10  0.14  0.10  0.11  0.08  0.07  ...  0.09
#
#      z1    z2    z3    z4    z5    z6    z7    z8    z9
# 0  0.08  0.09  0.12  0.10  0.10  0.08  0.11  0.12  0.10
# 1  0.11  0.11  0.09  0.12  0.10  0.11  0.10  0.07  0.08
# 2  0.11  0.10  0.09  0.08  0.11  0.11  0.09  0.10  0.12
# 3  0.10  0.11  0.10  0.09  0.07  0.12  0.14  0.07  0.11
# 4  0.09  0.11  0.10  0.11  0.11  0.08  0.09  0.14  0.10
#
# [5 rows x 28 columns]

# %%
# Use train_test_split to create training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=40)

# %%
y_train
# Out:
# 5034    1
# 154     5
# 58      5
# 540     1
# 3536    0
#        ..
# 3603    1
# 4722    1
# 3340    4
# 3064    4
# 3398    5
# Name: ActivityEncoded, Length: 4063, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data
X_scaler = StandardScaler().fit(X_train)

# %% [raw]
# #Transform the training and testing data using the X_scaler
#
# X_train_scaled = X_scaler.transform(X_train)
# X_test_scaled = X_scaler.transform(X_test)

# %%
# from tensorflow.keras.utils import to_categorical

# %%
# # One-hot encoding
# y_train_categorical = to_categorical(y_train)
# y_test_categorical = to_categorical(y_test)

# %%
# first, create a normal neural network with 2 inputs, 6 hidden nodes, and 2 outputs
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense

# model = Sequential()
# model.add(Dense(units=6, activation='relu', input_dim=30))
# model.add(Dense(units=2, activation='softmax'))

# %%
import numpy as np

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-5eaa7204c963> in <module>
# ----> 1 from tensorflow.keras.models import Sequential
#       2 from tensorflow.keras.layers import Dense
#
# ModuleNotFoundError: No module named 'tensorflow.keras'

# %%
import tensorflow as tf
from tensorflow.python import keras

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5eaa7204c963> in <module>
# ----> 1 from tensorflow.keras.models import Sequential
#       2 from tensorflow.keras.layers import Dense
#
# ModuleNotFoundError: No module named 'tensorflow.keras'

# %%
from tensorflow.python.keras.layers import Input, Dense
